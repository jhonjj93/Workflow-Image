# %%
import controller_layer as ct
import visualization_layer as vl
import matplotlib.pyplot as plt

# %% [markdown]
# # Define the path of the project directory:

# %%
Dir = r"C:\Users\Usuario\gis\Workflow images"

# %% [markdown]
# # This line generate the data from the orthomosaics:

# %%
a=ct.stat_ext_4cylces(Dir,"CYCLE1","CASANARE","FIELD36")

# %% [markdown]
# # This line organize, consolidate and plot the data

# %%
ordered_data=ct.reorder(Dir,"CYCLE1","CASANARE","FIELD36")
consolidated_data=ct.create_consolidated_dataframe(ordered_data,"mean",Dir,"CYCLE1","CASANARE","FIELD36")
vl.pl([["LAI","NDVI_mean"],["THM_mean","SPAD"],["DB","PH"],["K","R"]],consolidated_data)
